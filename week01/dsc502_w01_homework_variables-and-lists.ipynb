# %% [markdown]
# # DSC502: Coding — Week 1 Homework
# ## RideAlong Ride-Hailing Platform
# ### Regent's University London
#
# ---
#
# ## The scenario
#
# RideAlong is a fictional ride-hailing platform — think of it as a competitor to Uber operating across several UK cities. The platform connects passengers with drivers, tracks trips, and collects ratings after each ride. Over the next few weeks, we will use RideAlong data in homework exercises to put the concepts we have learned into practice.
#
# This week, your task is straightforward: use the same Python you practised in the session — variables, data types, f-strings, and lists — applied to a new scenario and dataset.
#
# ---
#
# ## Before you start
#
# **AI assistance rule:** No AI generation. Same rule as the session notebook. You write everything yourself. If you hit an error you genuinely cannot decode, you may ask AI to *explain the error message* — but not to fix or write your code.
#
# **Commentary cells are required** after every exercise. These are not optional — they are how you demonstrate that you understand what you wrote, not just that you got it to run.
#
# **How to submit:** push to GitHub when done.
# ```bash
# git add . && git commit -m "week 1 homework" && git push
# ```
#
# ---

# %% [markdown]
# ## Exercise 1 — Driver profile
#
# RideAlong stores a profile for each registered driver.
#
# Create the following variables for a fictional RideAlong driver:
# - `driver_name` — the driver's full name (string)
# - `years_experience` — how many years they have been driving for the platform (integer)
# - `average_rating` — their average passenger rating out of 5 (float)
# - `currently_available` — whether they are currently accepting ride requests (bool)
#
# Then:
# 1. Print each variable
# 2. Print the type of each variable using `type()`
# 3. Write an f-string that reads: `"Driver [name] has [X] years of experience and is currently available."` — write this sentence *twice* by hand: once with `"available"` and once with `"unavailable"`. Do not use an if statement — just write both versions manually and print them both.

# %%
# Exercise 1 — your code here

# %% [markdown]
# ### Stretch task
#
# What happens if you try to add `average_rating` (float) to `years_experience` (int)? Try it. Then try adding `average_rating` to `driver_name` (string). Try both and explain what happens in each case.

# %%
# Stretch — try both additions and observe the results

# %% [markdown]
# ### Commentary cell 1
#
# *Double-click this cell to edit it. Write at least 3–5 sentences.*
#
# **In your own words:** What is the difference between a float and an integer? When would you use each in a real application — give a specific example from the RideAlong context. What did you find out from the stretch task? Where did you get stuck (if anywhere) and what did you do about it?

# %% [markdown]
# *(your answer here)*

# %% [markdown]
# ---
#
# ## Exercise 2 — City list
#
# RideAlong currently operates in several UK cities.
#
# 1. Create a list called `active_cities` containing at least **seven** city names where RideAlong operates. Make them realistic UK cities.
# 2. Print the first city in the list
# 3. Print the last city in the list (use negative indexing)
# 4. Print the total number of cities using `len()`
# 5. Add a new city to the list using `.append()`
# 6. Print the first three cities using slicing
# 7. Check whether `"Edinburgh"` is in the list. Print a sentence using an f-string with the result — something like: `"Edinburgh is an active RideAlong city: True"`

# %%
# Exercise 2 — your code here

# %% [markdown]
# ### Stretch task
#
# Sort `active_cities` alphabetically using `.sort()`. What does the list look like after sorting? Now try creating a list of numbers and sorting that. Does `.sort()` behave the same way with numbers as with strings?

# %%
# Stretch — sort both lists

# %% [markdown]
# ### Commentary cell 2
#
# *Double-click this cell to edit it. Write at least 3–5 sentences.*
#
# **In your own words:** What does indexing mean in Python — why does the first item live at position 0 rather than position 1? Slicing with `[0:3]` gives you items at index 0, 1, and 2 but *not* 3 — why do you think Python works this way? What would a real operations team at RideAlong use a list like `active_cities` for?

# %% [markdown]
# *(your answer here)*

# %% [markdown]
# ---
#
# ## Exercise 3 — Trip summary
#
# When a RideAlong trip is completed, the platform records a summary.
#
# 1. Create the following variables for a completed trip:
#    - `driver_name` — the driver's name (string)
#    - `distance_km` — distance of the trip in kilometres (float)
#    - `fare_gbp` — the fare charged in pounds (float)
#    - `passenger_rating` — the passenger's rating out of 5 (float)
#
# 2. Print a formatted trip summary using an f-string:
#    `"Driver [name] completed a [X]km trip. Fare: £[Y]. Rating: [Z]/5."`
#
# 3. Create a list called `recent_fares` containing three fare amounts from different trips (make them up). Print the list.

# %%
# Exercise 3 — your code here

# %% [markdown]
# ### Stretch task
#
# Without using any functions you have not learned yet (no `max()`, no `sum()`), can you print the highest fare in `recent_fares`?
#
# Hint: you can sort a list and then index the last item. Try it, then explain in your commentary cell what you did and why it works.

# %%
# Stretch — find the highest fare using only what you know

# %% [markdown]
# ### Commentary cell 3
#
# *Double-click this cell to edit it. Write at least 3–5 sentences.*
#
# **In your own words:** What did you find hardest in this exercise? What error messages did you encounter and what did they tell you? If you attempted the stretch task, explain what you did and why it worked (or why it didn't).

# %% [markdown]
# *(your answer here)*

# %% [markdown]
# ---
#
# ## Final reflection
#
# *Double-click this cell to edit it. Answer all three questions — a few sentences each is fine.*
#
# 1. What was the hardest part of this homework overall?
#
# 2. Did you ask AI for help at any point? If so, what did you ask and what did it tell you?
#
# 3. How do you think working without AI this week will affect how you use it from Week 2 onwards?

# %% [markdown]
# *(your answers here)*

# %% [markdown]
# ---
#
# ## Submitting your work
#
# Push your completed notebook to GitHub from the Codespaces terminal:
#
# ```bash
# git add . && git commit -m "week 1 homework" && git push
# ```
#
# **Check:** your repo URL should already be posted in your Blackboard Journal from the Week 1 session. If it is not there yet, post it now — that URL is your submission anchor for the whole module.
